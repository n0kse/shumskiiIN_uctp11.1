# %%
import pandas as pd

# %%
import redis as rd

# %%
D=pd.read_excel("https://github.com/junaart/ForStudents/raw/refs/heads/main/R/Zachet/DataSets/5.xlsx")
D
# Out:
#                  town1  Sum-Avg-Р811  Sum-Avg-Р812   Sum-Avg-Р813  \
# 0               Абакан  1.918825e+03     8954.6250      33.725000
# 1       Азовский район  6.811933e+03        0.0000       0.000000
# 2      Аксайский район  7.125582e+04        0.0000       0.000000
# 3    Алексеевкий район  1.230500e+03        0.0000       0.000000
# 4                Анапа  8.225300e+03        0.0000       0.000000
# ..                 ...           ...           ...            ...
# 276     Южно-Сахалинск  4.128817e+05     6014.1500  133902.700000
# 277             Якутск  1.711287e+06   136877.2175   88569.590500
# 278               Ялта  3.921625e+05   111159.7000     925.000000
# 279          Ярославль  2.688059e+05   204442.7000   92436.108333
# 280  Ярославский район  1.544818e+04        0.0000       0.000000
#
#      Sum-Avg-Р814   Sum-Avg-Р815  Sum-Avg-Р821  Sum-Avg-Р822  Sum-Avg-Р823  \
# 0      1796.25000   11138.525000  2.541233e+04      130.3000       30.0000
# ...

# %%
r=rd.Redis(host='localhost', db=0)
key = "col"
for i in range(len(D['Sum-Avg-Р811'])):
    r.set(key+str(i),str(D['Sum-Avg-Р811'].iloc[i]))

# %%
r=rd.Redis(host='localhost', db=0)
key = "col2"
for i in range(len(D['Sum-Avg-Р812'])):
    r.set(key+str(i),str(D['Sum-Avg-Р812'].iloc[i]))

# %%
r=rd.Redis(host='localhost', db=0)
key = "col3"
for i in range(len(D['Sum-Avg-Р813'])):
    r.set(key+str(i),str(D['Sum-Avg-Р813'].iloc[i]))

# %%
r=rd.Redis(host='localhost', db=0)
key = "col4"
for i in range(len(D['Sum-Avg-Р814'])):
    r.set(key+str(i),str(D['Sum-Avg-Р814'].iloc[i]))

# %%
r=rd.Redis(host='localhost', db=0)
key = "col5"
for i in range(len(D['Sum-Avg-Р815'])):
    r.set(key+str(i),str(D['Sum-Avg-Р815'].iloc[i]))

# %%
r=rd.Redis(host='localhost', db=0)
key = "col6"
for i in range(len(D['Sum-Avg-Р821'])):
    r.set(key+str(i),str(D['Sum-Avg-Р821'].iloc[i]))

# %%
r=rd.Redis(host='localhost', db=0)
key = "col7"
for i in range(len(D['Sum-Avg-Р821'])):
    r.set(key+str(i),str(D['Sum-Avg-Р821'].iloc[i]))

# %%
r=rd.Redis(host='localhost', db=0)
key = "col8"
for i in range(len(D['Sum-Avg-Р822'])):
    r.set(key+str(i),str(D['Sum-Avg-Р822'].iloc[i]))

# %%
r=rd.Redis(host='localhost', db=0)
key = "col9"
for i in range(len(D['Sum-Avg-Р823'])):
    r.set(key+str(i),str(D['Sum-Avg-Р823'].iloc[i]))

# %%
r=rd.Redis(host='localhost', db=0)
key = "col10"
for i in range(len(D['Sum-Avg-Р824'])):
    r.set(key+str(i),str(D['Sum-Avg-Р824'].iloc[i]))

# %%
r=rd.Redis(host='localhost', db=0)
key = "col11"
for i in range(len(D['Sum-Avg-Р825'])):
    r.set(key+str(i),str(D['Sum-Avg-Р825'].iloc[i]))

# %%
r=rd.Redis(host='localhost', db=0)
key = "col12"
for i in range(len(D['Sum-Avg-Р826'])):
    r.set(key+str(i),str(D['Sum-Avg-Р826'].iloc[i]))
